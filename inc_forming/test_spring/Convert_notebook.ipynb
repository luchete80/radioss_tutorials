# %% [markdown]
# # Multi Tool path Gen

# %%
import csv
import numpy as np
import pandas as pd

###### PARAM ENTRADA ##############
##### ASSUMES THAT UNITS ARE MM####
## AND CSV IS IN MM
vel = 4000.0; #mm/min
#THEY ARE USED TO CORRECT INITIAL Z
gap_0       = 0.0e-4
dt_dum      = 1.0e-3 #Positioning
thck        = 5.0e-4

av_dist = 0.9
dt = av_dist  / vel
#NEW, THIS ACCOMODATES TOOL TO ABS Z POSITION
t_interf = 1.0
#### IN TOP TOOL t/2 + disp = zabs
#ZABS IS GIVEN BY TOOLTIP POINTS
#disp = zabs - t/2
###################################
def writeFloatField(number, length, decimals):
    fmt ='%.' + str(decimals) + 'e'
    # print ('format ' + fmt)
    s = fmt % number
    spaces = ''
    for i in range ((int)(length - len(s))):
        spaces = spaces + ' '
    output = spaces + s
    # print (spaces + s)
    return output

def get_InitialXY(fname):
    file = open(fname)
    reader = csv.reader(file)
    data = list(csv.reader(file, delimiter=','))

    ret = (1.0e-3*float (data[1][0]), 1.0e-3*float (data[1][1]))
    print("InitialXY is: ", ret)
    return ret

def multitool_rewrite(fnametop,fnamebot=None,multi_tool_N=4,step_angle=90):
    
    step_angle
    angles=np.arange(0,360,step_angle)
    print(angles)
    
    if fnamebot==None:
        data=pd.read_csv(fnametop)
        data.to_csv(f'multi_tool_{0}.csv',index=False)
        out_top=pd.DataFrame()

        if multi_tool_N>1:
            for i,angle in enumerate(angles[1:]):
                #const
                sin=np.sin(angle*np.pi/180)
                cos=np.cos(angle*np.pi/180)
                
                out_top["X"]=cos*data.X-sin*data.Y
                out_top["Y"]=sin*data.X+cos*data.Y
                out_top['Z']=data.Z
        
                #out_bot["X"]=cos*data2.X-sin*data2.Y
                #out_bot["Y"]=sin*data2.X+cos*data2.Y
                #out_bot['Z']=data2.Z
                
                out_top.to_csv('multi_tool_'+str(i*2+2)+'.csv',index=False)
                #out_bot.to_csv('multi_tool_'+str(i*2+3)+'.csv',index=False)
                #plt.plot(out_top.X,out_top.Y)
        
        files=[]   
        for k in range(multi_tool_N):
            print(k)
            files.append(f'multi_tool_{k*2}.csv')
            
    else:
        data=pd.read_csv(fnametop)
        data2=pd.read_csv(fnamebot)
    
    
        data.to_csv(f'multi_tool_{0}.csv',index=False)
        data2.to_csv(f'multi_tool_{1}.csv',index=False)
        
        
        #data["radio"] = (data.X**2+data.Y**2)**0.5
        #data2["radio"] = (data2.X**2+data2.Y**2)**0.5
    
        out_top=pd.DataFrame()
    
        out_bot=pd.DataFrame()
    
        if multi_tool_N>2:
            for i,angle in enumerate(angles[1:]):
                #const
                sin=np.sin(angle*np.pi/180)
                cos=np.cos(angle*np.pi/180)
                
                out_top["X"]=cos*data.X-sin*data.Y
                out_top["Y"]=sin*data.X+cos*data.Y
                out_top['Z']=data.Z
        
                out_bot["X"]=cos*data2.X-sin*data2.Y
                out_bot["Y"]=sin*data2.X+cos*data2.Y
                out_bot['Z']=data2.Z
                
                out_top.to_csv('multi_tool_'+str(i*2+2)+'.csv',index=False)
                out_bot.to_csv('multi_tool_'+str(i*2+3)+'.csv',index=False)
                #plt.plot(out_top.X,out_top.Y)
        
        files=[]        
        #print(i)
        for k in range(multi_tool_N):
            print(k)
            files.append(f'multi_tool_{k}.csv')
        
    return files

# %%
np.arange(0,360,90)
# Out:
# array([  0,  90, 180, 270])

# %%
def convert_multi_tool_v2(filenames,double_sided=True,multi_tool_N=2):

    if double_sided==False:
        print('tool displacements calculated for SPIF')
        for i in range(0,len(filenames),1):
            
            out_x = open(f'movi_x{i}.inc',"w")
            out_y = open(f'movi_y{i}.inc',"w")
            out_z = open(f'movi_z{i}.inc',"w")     

            fname=filenames[i]
            
            print (fname)
            
            file = open(fname)
            
            reader = csv.reader(file)
            
            data = list(csv.reader(file, delimiter=','))
            
            pt_count=len(data)-1
            print(data[1][1])
            print("Point Count: ", pt_count)
    
            funs=[(i*3) + 1 , (i*3) + 2, (i*3) + 3]
    
            print("top tools functions",funs)
    
            s=[f"{num:03d}" for num in funs ]
            
            out_x.write( f"/FUNCT/1000{s[0]}\nmovx\n")
            out_y.write( f"/FUNCT/1000{s[1]}\nmovy\n")
            out_z.write( f"/FUNCT/1000{s[2]}\nmovz\n")
            
            f = 1.0e-3
            x = [float(data[1][0]), float(data[1][1]), float (data[1][2])]
            xo = f * float (data[1][0])
            yo = f * float (data[1][1])
            zo = f * float (data[1][2])
            
            print ("First Point: ", x)
            avg_d=0.0
            t = 0.0    
    
            #TOP TOOL
            out_x.write(writeFloatField(t*60.0,20,10) + writeFloatField(0.0,20,10) + "\n")
            out_y.write(writeFloatField(t*60.0,20,10) + writeFloatField(0.0,20,10) + "\n")
            out_z.write(writeFloatField(t*60.0,20,10) + writeFloatField(0.0,20,10) + "\n")
        
            out_x.write(writeFloatField(t_interf,20,10) + writeFloatField(0.0,20,10) + "\n")
            out_y.write(writeFloatField(t_interf,20,10) + writeFloatField(0.0,20,10) + "\n")
            out_z.write(writeFloatField(t_interf,20,10) + writeFloatField(zo-thck/2.0, 20,10) + "\n")
    
            err_count = 0
    
            for i in range (2, len(data)):
                xp = np.array(data[i-1])
                # x = np.array(data[i])
                # x = np.array([float(data[i][0]), float(data[i][1]), float (data[i][2])])
    
                #TOP TOOL
                x = np.array([float(data[i][0]), float(data[i][1]), float (data[i][2])])
                xp = np.array([float(data[i-1][0]), float(data[i-1][1]), float (data[i-1][2])])
                #BOT TOOL
                
                # xp = data[i-1]
                #lst1 = [10,20,30,40,50]
                dist = np.linalg.norm(x-xp)
                avg_d = avg_d + dist
                v = x -xp
                # print ("x xp v dist", x, xp, v, dist)
                # print ("norm" )
                # print (i, data[i][0], data[i][1] ,data[i][2])
                # print (i, x[0], x[1] ,x[2])
                if (dist > 1.0e-6):
                    dt = dist/vel
                else:
                    err_count +=1
                t = t + dt
    
                out_x.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*x[0] - xo,20,10) + "\n")
                out_y.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*x[1] - yo,20,10) + "\n")
                out_z.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*x[2]-thck/2.0,20,10) + "\n")
    
            
        #    else:
        #        print("WARNING IN POINT"+ str(i)+", DISTANCE LESS THAN 1E-5")
                
            t +=10.0*dt
            out_x.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*x[0] - xo, 20,10) + "\n")
            out_y.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*x[1] - yo, 20,10) + "\n")
            out_z.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*x[2]-thck/2.0+1.0e-2,20,10) + "\n")
                    
            # The type of file is “_io.TextIOWrapper” which is a file object that is returned by the open()
            # type(file)
            avg_d = avg_d/pt_count
            print ("Avg distance: ", avg_d)
            print ("Segments witgh distance > 1.0e-6: ", err_count, " of ", len(data))
            out_x.close,out_y.close,out_z.close


    else:
        print('tool displacements calculated for DSIF / ADSIF')

####TOP TOOLS################################################################
        for i in range(0,len(filenames),2):
            
            out_x = open(f'movi_x{i}.inc',"w")
            out_y = open(f'movi_y{i}.inc',"w")
            out_z = open(f'movi_z{i}.inc',"w")     
            bout_x = open(f'movi_x{i+1}.inc',"w")
            bout_y = open(f'movi_y{i+1}.inc',"w")
            bout_z = open(f'movi_z{i+1}.inc',"w")
    
            fname=filenames[i]
            bfname=filenames[i+1]
            
            print (fname)
            print (bfname)
            
            file = open(fname)
            bfile = open(bfname)
            
            reader = csv.reader(file)
            breader = csv.reader(bfile)
    
            
            data = list(csv.reader(file, delimiter=','))
            bdata = list(csv.reader(bfile, delimiter=','))
    
            
            pt_count=len(data)-1
            print(data[1][1])
            print("Point Count: ", pt_count)
    
            funs=[(i*3) + 1 , (i*3) + 2, (i*3) + 3, (i*3) + 4 , (i*3) + 5, (i*3) + 6]
    
            print("top&bot tools functions",funs)
    
            s=[f"{num:03d}" for num in funs ]
            
            out_x.write( f"/FUNCT/1000{s[0]}\nmovx\n")
            out_y.write( f"/FUNCT/1000{s[1]}\nmovy\n")
            out_z.write( f"/FUNCT/1000{s[2]}\nmovz\n")
            bout_x.write(f"/FUNCT/1000{s[3]}\nmovx\n")
            bout_y.write(f"/FUNCT/1000{s[4]}\nmovy\n")
            bout_z.write(f"/FUNCT/1000{s[5]}\nmovz\n")
    
            
            f = 1.0e-3
            x = [float(data[1][0]), float(data[1][1]), float (data[1][2])]
            xo = f * float (data[1][0])
            yo = f * float (data[1][1])
            zo = f * float (data[1][2])
    
            bx = [float(bdata[1][0]), float(bdata[1][1]), float (bdata[1][2])]
            bxo = f * float (bdata[1][0])
            byo = f * float (bdata[1][1])
            bzo = f * float (bdata[1][2])
            
            print ("First Point: ", x)
            avg_d=0.0
            t = 0.0    
    
            #TOP TOOL
            out_x.write(writeFloatField(t*60.0,20,10) + writeFloatField(0.0,20,10) + "\n")
            out_y.write(writeFloatField(t*60.0,20,10) + writeFloatField(0.0,20,10) + "\n")
            out_z.write(writeFloatField(t*60.0,20,10) + writeFloatField(0.0,20,10) + "\n")
        
            out_x.write(writeFloatField(t_interf,20,10) + writeFloatField(0.0,20,10) + "\n")
            out_y.write(writeFloatField(t_interf,20,10) + writeFloatField(0.0,20,10) + "\n")
            out_z.write(writeFloatField(t_interf,20,10) + writeFloatField(zo-thck/2.0, 20,10) + "\n")
    
            #BOT TOOL
            bout_x.write(writeFloatField(t*60.0,20,10) + writeFloatField(0.0,20,10) + "\n")
            bout_y.write(writeFloatField(t*60.0,20,10) + writeFloatField(0.0,20,10) + "\n")
            bout_z.write(writeFloatField(t*60.0,20,10) + writeFloatField(0.0,20,10) + "\n")
    
            bout_x.write(writeFloatField(t_interf,20,10) + writeFloatField(0.0,20,10) + "\n")
            bout_y.write(writeFloatField(t_interf,20,10) + writeFloatField(0.0,20,10) + "\n")
            bout_z.write(writeFloatField(t_interf,20,10) + writeFloatField(bzo+thck/2.0, 20,10) + "\n")
        
            err_count = 0
    
            for i in range (2, len(data)):
                xp = np.array(data[i-1])
                # x = np.array(data[i])
                # x = np.array([float(data[i][0]), float(data[i][1]), float (data[i][2])])
    
                #TOP TOOL
                x = np.array([float(data[i][0]), float(data[i][1]), float (data[i][2])])
                xp = np.array([float(data[i-1][0]), float(data[i-1][1]), float (data[i-1][2])])
                #BOT TOOL
                bx = np.array([float(bdata[i][0]), float(bdata[i][1]), float (bdata[i][2])])
                bxp = np.array([float(bdata[i-1][0]), float(bdata[i-1][1]), float (bdata[i-1][2])])
                
                # xp = data[i-1]
                #lst1 = [10,20,30,40,50]
                dist = np.linalg.norm(x-xp)
                avg_d = avg_d + dist
                v = x -xp
                # print ("x xp v dist", x, xp, v, dist)
                # print ("norm" )
                # print (i, data[i][0], data[i][1] ,data[i][2])
                # print (i, x[0], x[1] ,x[2])
                if (dist > 1.0e-6):
                    dt = dist/vel
                else:
                    err_count +=1
                t = t + dt
    
                out_x.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*x[0] - xo,20,10) + "\n")
                out_y.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*x[1] - yo,20,10) + "\n")
                out_z.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*x[2]-thck/2.0,20,10) + "\n")
    
                bout_x.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*bx[0] - bxo,20,10) + "\n")
                bout_y.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*bx[1] - byo,20,10) + "\n")
                bout_z.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*bx[2] +thck/2.0,20,10) + "\n")
    
            
        #    else:
        #        print("WARNING IN POINT"+ str(i)+", DISTANCE LESS THAN 1E-5")
                
            t +=10.0*dt
            out_x.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*x[0] - xo, 20,10) + "\n")
            out_y.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*x[1] - yo, 20,10) + "\n")
            out_z.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(5.0,20,10) + "\n")
    
            bout_x.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*x[0] - bxo, 20,10) + "\n")
            bout_y.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*x[1] - byo, 20,10) + "\n")
            bout_z.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(-5.0,20,10) + "\n")
                    
            # The type of file is “_io.TextIOWrapper” which is a file object that is returned by the open()
            # type(file)
            avg_d = avg_d/pt_count
            print ("Avg distance: ", avg_d)
            print ("Segments witgh distance > 1.0e-6: ", err_count, " of ", len(data))
            out_x.close,out_y.close,out_z.close
            bout_x.close,bout_y.close,bout_z.close


####BOTOM TOOLS################################################################

    # for i in range(1,len(filenames),2):

    #     fname=filenames[i]
    #     print (fname)
        
    #     out_x = open(f'movi_x{i}.inc',"w")
    #     out_y = open(f'movi_y{i}.inc',"w")
    #     out_z = open(f'movi_z{i}.inc',"w")
    
    #     file = open(fname)
    #     reader = csv.reader(file)
    #     data = list(csv.reader(file, delimiter=','))
    #     pt_count=len(data)-1

    #     print (data[1][1])
    #     print ("Point Count: ", pt_count)

    #     funs=[(i*3) + 1 , (i*3)+2, (i*3) + 3 ]

    #     s=[f"{num:03d}" for num in funs ]
        
    #     print("bot tols",funs)
        
    #     out_x.write(f"/FUNCT/1000{s[0]}\nmovx\n")
    #     out_y.write(f"/FUNCT/1000{s[1]}\nmovy\n")
    #     out_z.write(f"/FUNCT/1000{s[2]}\nmovz\n") 
    


    #     f = 1.0e-3
    #     x = [float(data[1][0]), float(data[1][1]), float (data[1][2])]
    #     xo = f * float (data[1][0])
    #     yo = f * float (data[1][1])
    #     zo = f * float (data[1][2])
        
    #     print("First Point: ", x)
    #     avg_d=0.0
    #     t=0.0    
    
    #     out_x.write(writeFloatField(t*60.0,20,10) + writeFloatField(0.0,20,10) + "\n")
    #     out_y.write(writeFloatField(t*60.0,20,10) + writeFloatField(0.0,20,10) + "\n")
    #     out_z.write(writeFloatField(t*60.0,20,10) + writeFloatField(0.0,20,10) + "\n")

    #     out_x.write(writeFloatField(t_interf,20,10) + writeFloatField(0.0,20,10) + "\n")
    #     out_y.write(writeFloatField(t_interf,20,10) + writeFloatField(0.0,20,10) + "\n")
    #     out_z.write(writeFloatField(t_interf,20,10) + writeFloatField(zo+thck/2.0, 20,10) + "\n")
        
    #     err_count = 0
        
    #     for i in range (2, len(data)):
            
    #         x = np.array([float(data[i][0]), float(data[i][1]), float (data[i][2])])
    #         xp = np.array([float(data[i-1][0]), float(data[i-1][1]), float (data[i-1][2])])

    #         lst1 = [10,20,30,40,50]
    #         dist = np.linalg.norm(x-xp)
    #         avg_d = avg_d + dist
    #         v = x -xp
    #         # print ("x xp v dist", x, xp, v, dist)
    #         # print ("norm" )
    #         # print (i, data[i][0], data[i][1] ,data[i][2])
    #         # print (i, x[0], x[1] ,x[2])
    #         if (dist > 1.0e-6):
    #             dt = dist/vel
    #         else:
    #             err_count +=1        
    #         t = t + dt

    #         out_x.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*x[0] - xo,20,10) + "\n")
    #         out_y.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*x[1] - yo,20,10) + "\n")
    #         out_z.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*x[2] +thck/2.0,20,10) + "\n")
    #         #else:
    #         #    print("ERROR, POINT DISTANCE LESS THAN 1E-5")
            
    #     t +=10.0*dt
    #     out_x.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*x[0] - xo, 20,10) + "\n")
    #     out_y.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(f*x[1] - yo, 20,10) + "\n")
    #     out_z.write(writeFloatField(t*60.0+t_interf,20,10) + writeFloatField(-5.0,20,10) + "\n")
                
    #     # The type of file is “_io.TextIOWrapper” which is a file object that is returned by the open()
    #     # type(file)
    #     avg_d = avg_d/pt_count
    #     print ("Avg distance: ", avg_d)
    #     print ("Segments witgh distance > 1.0e-6: ", err_count, " of ", len(data))
    #     out_x.close,out_y.close,out_z.close

# %%
#funnames=[]

#mult_tool_N=8
#for i in range(multi_tool_N)
#    funname.append(f'movi_x{i}.inc')
#    funname.append(f'movi_y{i}.inc')
#    funname.append(f'movi_z{i}.inc')

# import pandas as pd
# import numpy as np
# step_angle=90
# angles=np.arange(90,360,step_angle)
# print(angles)

# data=pd.read_csv("data/multitool_topToolTipPnts.csv")

# for angle in angles:
#     #const
#     sin=np.sin(angle*np.pi/180)
#     cos=np.cos(angle*np.pi/180)
#     data["radio"] = (data.X**2+data.Y**2)**0.5
#     data["X"+str(angle)]=cos*data.radio
#     data["Y"+str(angle)]=sin*data.radio

# data.head()

# %%
files=multitool_rewrite("data/MESIC_55_topToolTipPnts.csv",multi_tool_N=1,step_angle=360)

#files=multitool_rewrite("data/multitool_topToolTipPnts.csv","data/multitool_botToolTipPnts.csv",multi_tool_N=16,step_angle=45)
print(files)
convert_multi_tool_v2(files,double_sided=False,multi_tool_N=1)
# Out:
# [0]
# 0
# ['multi_tool_0.csv']
# tool displacements calculated for SPIF
# multi_tool_0.csv
# -0.0
# Point Count:  45113
# top tools functions [1, 2, 3]
# First Point:  [84.2448, -0.0, -0.0263]
# Avg distance:  1.789772156910845
# Segments witgh distance > 1.0e-6:  241  of  45114

# %% [markdown]
# # ADSIF_GEN

# %%
#https://www.tutorialsteacher.com/python/create-ui-using-tkinter-in-python
from math import *
from mesher import *
import numpy as np
import csv
import sys

# from tkinter import *
# from tkinter.ttk import Combobox
from enum import Enum

# window=Tk()
linea_g=10

flog = open("log.txt","w")

#################### INPUT VARS

#WORKPIECE
largo = 0.22
delta = 0.0015
thck  = 5.8e-4      #Plate Thickness
thck_rig = 1.0e-4   #BALL
thck_supp = 1.0e-4  #SUPP

#TOOL (IF CALC PATH)
r_i           = 0.0     #Inner Path Radius
r_o           = 0.0     #Outer Path Radius

#TOOL (IT NOT CALC PATH)
topfname = "data/MESIC_55_topToolTipPnts.csv"
botfname = "data/multitool_botToolTipPnts.csv"



mm       = 1.0e-3 #IF UNITS ARE IN MM

r             = 0.0325
dr            = 5.0e-4    #DESAPARECE DE ACUERDO A LA GEOMETRIA
dt            = 1.0e-5    #Time increment for path gen
#t_ang         = 1.0e-3    #Periodo angular, ANTES ERA CONSTANTE
p_D           = 2.5e-3     #ASDIF RADIAL DISTANCE BETWEEN TOOLS
p_S           = 4.3e-4     #ASDIF HEIGHT DISTANCE BETWEEN TOOLS
tool_speed    = 0.6 / 60.0 * 5000 #3000mm/min according to Valoppi
t_ind         = 1.0e-3
tool_rad      = 0.00705    #Tool radius
gap           = 0.0e-4
gap_cont      = -2.5e-4 #-2.5e-4
dtout         = 1.0
dtout_his     = 1.0e-4
#end_time      = 2405.0 infered from files:
v_supp        = 1.0e-3
supp_rel_time = 10.0
supp_vel_ramp = True
dynrel_time   = 5.0
## SCALING
vscal_fac     = 1.0 #Affects All magnitudes with s^-1: Tool Speed, HEAT CONDUCTIVIY, CONVECTION
dampfac       = 100.0
tool_springs  = True

###### SUPPORT
dens_supp_1 = 5
dens_supp_2 = 60
largo_supp = 0.005

###### CENTER OF PIECE 
x_init              = r_i  #DO NOT PUT xo! USED AS x OUTPUT IN DOUBLE SIDED
x_init_o            = r_o  #DO NOT PUT xo! USED AS x OUTPUT IN DOUBLE SIDED
move_tool_to_inipos = True # THIS IS CONVENIENT, OTHERWISE RADIOSS THROWS ERROR DUE TO LARGE DISP TO INITIAL POS
                           #ONLY USED IF NOT CALC PATH
thermal             = True
cont_support        = True       #TRUE: SUPPORT IS MODELED BY CONTACT, FALSE: SUPPORT IS MODELED BY BCS ON NODES
double_sided        = False
calc_path           = False
mass_scal           = True
ms_dtsize           = 1.0e-4

multi_tool          = False
multi_tool_stp_angle= 360
multi_tool_N        = 1 
tool_temp           = 50.0
stiff_x             = 3.9690e5
stiff_y             = 2.6898e5
stiff_z             = 1.3130e6

cyl_mesh            = True #CHANGES LINE 212: shell_mesh.Plane_gmsh(shell_mesh, 0.1,0.005,r_large-0.085,r_large,0.22)

#=====================================================================================================
if multi_tool:
    if double_sided:
        topfname = "data/MESIC_55_topToolTipPnts.csv"
        botfname = "data/multitool_botToolTipPnts.csv"
    else:
        topfname = "data/MESIC_55_topToolTipPnts.csv"
        botfname = None        
else:
    if double_sided:
        multi_tool_N=2 #NO EDIT
        multi_tool_stp_angle=360 #NO EDIT
    else:
        multi_tool_N=1
        multi_tool_stp_angle=360 #NO EDIT
        


Ti6Al4V=False
AISI430=True

if Ti6Al4V:
    ###### MATERIAL
    mat = Material(1,thermal) #ID, THERMAL
    mat.rho     = 4430.0
    mat.E       = 105.0e9
    mat.nu      = 0.34
    mat.vs_fac  = vscal_fac
    
    #thermal
    mat.k_th  = 7.4 # 15 //
    mat.cp_th = 520.0
    
    mat.Ajc   = 790.0e6
    mat.Bjc   = 478.0e6
    mat.njc   = 0.28
    mat.mjc   = 1.0
    mat.Cjc   = 0.032
    mat.e0jc  = 1.0

if AISI430: #Verification of Johnson-Cook parameters of ferritic stainless steel by drilling process: experimental and finite element simulations
            #Mehmet Erdi Korkmaz (2020)
    
    ###### MATERIAL
    mat = Material(1,thermal) #ID, THERMAL
    mat.rho     = 7800.0
    mat.E       = 200.0e9
    mat.nu      = 0.3
    mat.vs_fac  = vscal_fac
    
    #thermal
    mat.k_th  = 26.1 # 15 //
    mat.cp_th = 460.0
    
    mat.Ajc   = 359.0e6
    mat.Bjc   = 327.0e6
    mat.njc   = 0.454
    mat.mjc   = 0.919
    mat.Cjc   = 0.0786
    mat.e0jc  = 0.04

##### SCALING
# class Scaling(Enum):
  # NONE   = 1       # 
  # VPROC  = 2       #Only on tool veloc 
  # MS_FIX = 3       #Fixed Mass scal, since cp 
  # VS_FIX = 4
  # AMS    = 5

# scal_type = Scaling.MS_FIX
# scal_fac  = 250.0          #ONLY WORKS WITH FIXE MS OR VS 

################################################## BEGIN ####################################################################################
#############################################################################################################################################
# if (scal_type == Scaling.NONE or scal_type == Scaling.VPROC or scal_type == Scaling.AMS):
  # scal_fac = 1.0

# filelbl = Label(window, text="Input File", width=15,justify=LEFT)
# filelbl.grid(column=1, row=0)	
# textField = Entry(window, width=15)
# textField.grid(column=2, row=0)
# textField.insert(0,"test")

if (not calc_path):
  try:
    print ("Reading Tool Path files to position tool")
    print (topfname + ", " + topfname)
      
    topf = open(topfname) #IN
    topdata = list(csv.reader(topf, delimiter=','))
    xy_i = [float(topdata[1][0])*mm,float(topdata[1][1])*mm]
    print ("Top    Init X and Y positions: ", xy_i[0],xy_i[1])

    if double_sided:
      botf = open(botfname) #OUT   
      botdata = list(csv.reader(botf, delimiter=','))  
      xy_o = [float(botdata[1][0])*mm,float(botdata[1][1])*mm]  
      print ("Bottom Init X and Y positions: ", xy_o[0],xy_o[1])  



    
  except IOError:
    print('There was an error opening the toolpaths files!')
    #return
    sys.exit()

test = [(1,1),(2,2)]
test.append((3,4))
print (test)
print (test[2][0])



supp_mesh = []
supp_part = []

shell_elnod = [(1,2,3,4)]

if (not cyl_mesh):
    shell_mesh = Plane_Mesh(1,largo,delta)
else:
    r_large = 0.18
    shell_mesh = Plane_Mesh(1)
    shell_mesh.Plane_gmsh(0.1,0.005,r_large-0.085,r_large,0.22)



print("X COORDS----------------------------- ")
shell_mesh.PrintCoords(0,1.00e-3,1.0e-5)
print("Y COORDS----------------------------- ")
shell_mesh.PrintCoords(1,1.00e-3,1.0e-5)

print()
if (calc_path):
  y_init = 0.0
  y_init_o = 0.0
  if (not move_tool_to_inipos):
    x_init   = 0.0  
    x_init_o = 0.0  
else:
  x_init=xy_i[0]     
  y_init=xy_i[1]
  if double_sided:  
    x_init_o=xy_o[0]  
    y_init_o=xy_o[1]
  
sph1_mesh = Sphere_Mesh(2, tool_rad,x_init, y_init,(tool_rad + thck/2.0 + gap + thck_rig/2.0),8) #(id, radius, divisions): #checkpoint

driver_top = Spring_Mesh(1002); #ID, Create Node count,
driver_top.add_node(x_init, y_init, (tool_rad + thck/2.0 + gap + thck_rig/2.0+2.0*tool_rad))
#Elements will be created once connectiovities are known (after tools node ids will be known)
#TODO: USE NODES ID

if (double_sided):
  sph2_mesh = Sphere_Mesh(3, tool_rad,        \
                        x_init_o, y_init_o,(-tool_rad - thck/2.0 - gap-thck_rig/2.0), \
                                        8) #(id, radius, divisions):

  driver_bot = Spring_Mesh(1003); #ID, Create Node count,
  driver_bot.add_node(x_init_o, y_init_o, (-tool_rad + -thck/2.0 - gap - thck_rig/2.0-2.0*tool_rad))


i=0
#MESHES FOR SPRINGS
driver_top_mesh_mt = []
count = 0
#============================================================================================================
####TODO, MAKE BOTTOM TOOLS APART
if multi_tool:

    sph_mesh=list()
    
    angles=list(np.arange(multi_tool_stp_angle,360,multi_tool_stp_angle))
    print("angulos", angles)

    #r_init_top=np.sqrt(x_init**2 + y_init**2)
    #r_init_bot=np.sqrt(x_init_o**2 + y_init_o**2)
    
    for i,angle in  enumerate(angles):
        print("i: ", i)
        sin=np.sin(angle*np.pi/180)
        cos=np.cos(angle*np.pi/180)

        # if double_sided: # extra pairs multi spheres created:

        #     ####BUT 
        #     sph_mesh.append(Sphere_Mesh(3+(i*2+1), tool_rad,        \
        #                             cos * x_init-sin*y_init, sin*x_init+cos*y_init, (tool_rad + thck/2.0 + gap + thck_rig/2.0),\
        #                             8)#(id, radius, divisions): \
        #                    )
            
        #     sph_mesh.append(Sphere_Mesh(3+(i*2+2), tool_rad,        \
        #                             cos * x_init_o-sin*y_init_o, sin*x_init_o+cos*y_init_o,(-tool_rad - thck/2.0 - gap-thck_rig/2.0), \
        #                             8) #(id, radius, divisions):\
        #                    )
        # else: # extra top multi spheres where created in 2 4 6 8...:
        sph_mesh.append(Sphere_Mesh(3+i, tool_rad,        \
                                cos * x_init-sin*y_init, sin*x_init+cos*y_init, (tool_rad + thck/2.0 + gap + thck_rig/2.0),\
                                8)#(id, radius, divisions): \
                       )
        print(f'>>>>>>>>>extra tool {i} mesh id: {sph_mesh[i].id}')


        #for i in range(multi_tool_N-1):
        driver_top_mesh_mt.append(Spring_Mesh(1002+i+1)); #ID, Create Node count,
        driver_top_mesh_mt[count].add_node(cos * x_init-sin*y_init, \
                                           sin*x_init+cos*y_init, (tool_rad + thck/2.0 + gap + thck_rig/2.0+2.0*tool_rad))
        print("Added spring Node at: ", cos * x_init-sin*y_init, sin*x_init+cos*y_init)
        count+=1
            


    else:
        i=0

print ("Part index i: ", i)

#============================================================================================================

                                        

if (cont_support):
    
  #Y-     support,                id,             lx,               ly,         elem_x,     elem_y,       ox,                   oy, z_, flip):
  supp_mesh.append(Rect_Plane_Mesh(2+multi_tool_N,largo+largo_supp,largo_supp,dens_supp_2,dens_supp_1, -largo/2.0-largo_supp/2.0, -largo/2.0           , -thck/2.0-gap_cont-thck_supp/2.0, False)) #Legth x,  
  supp_mesh[0].AddRigidNode(0.0,-largo/2.0, -2.0*thck)
  supp_mesh.append(Rect_Plane_Mesh(3+multi_tool_N,largo+largo_supp,largo_supp,dens_supp_2,dens_supp_1, -largo/2.0-largo_supp/2.0, -largo/2.0           ,  thck/2.0+gap_cont+thck_supp/2.0, True))
  supp_mesh[1].AddRigidNode(0.0,-largo/2.0,  2.0*thck)

  #Y+ support,                   id,lx,           ly,         elem_x,     elem_y,       ox,                   oy, z_, flip):
  supp_mesh.append(Rect_Plane_Mesh(4+multi_tool_N,largo+largo_supp,largo_supp,dens_supp_2,dens_supp_1, -largo/2.0-largo_supp/2.0,  largo/2.0-largo_supp, -thck/2.0-gap_cont-thck_supp/2.0, False))
  supp_mesh[2].AddRigidNode(0.0, largo/2.0, -2.0*thck)
  supp_mesh.append(Rect_Plane_Mesh(5+multi_tool_N,largo+largo_supp,largo_supp,dens_supp_2,dens_supp_1, -largo/2.0-largo_supp/2.0,  largo/2.0-largo_supp,  thck/2.0+gap_cont+thck_supp/2.0, True))
  supp_mesh[3].AddRigidNode(0.0, largo/2.0,  2.0*thck)
  
  #THESE SUPPORTS HAVE Y LENGTH SHORTER THAN OTHERS; ONLY Y LENGTH ON HEIGHT
  # #X-     support,                id,lx,        ly,          elem_x,     elem_y,       ox,               oy, z_, flip):  
  x_pos = largo/2.0
  supp_mesh.append(Rect_Plane_Mesh(6+multi_tool_N,largo_supp,largo-largo_supp,dens_supp_1,dens_supp_2, -x_pos,                     -largo/2.0+largo_supp/2.0, -thck/2.0-gap_cont-thck_supp/2.0, False))
  supp_mesh[4].AddRigidNode(-largo/2.0 ,0.0,  -2.0*thck)
  supp_mesh.append(Rect_Plane_Mesh(7+multi_tool_N,largo_supp,largo-largo_supp,dens_supp_1,dens_supp_2, -x_pos,                     -largo/2.0+largo_supp/2.0,  thck/2.0+gap_cont+thck_supp/2.0, True))
  supp_mesh[5].AddRigidNode(-largo/2.0 ,0.0,   2.0*thck)

  # #X+     support,                id,lx,        ly,        elem_x,     elem_y,       ox,               oy, z_, flip):  
  supp_mesh.append(Rect_Plane_Mesh(8+multi_tool_N,largo_supp,largo-largo_supp,dens_supp_1,dens_supp_2, x_pos-largo_supp,            -largo/2.0+largo_supp/2.0, -thck/2.0-gap_cont-thck_supp/2.0, False))
  supp_mesh[6].AddRigidNode(-largo/2.0 ,0.0,  -2.0*thck)
  supp_mesh.append(Rect_Plane_Mesh(9+multi_tool_N,largo_supp,largo-largo_supp,dens_supp_1,dens_supp_2, x_pos-largo_supp,            -largo/2.0+largo_supp/2.0,  thck/2.0+gap_cont+thck_supp/2.0, True))
  supp_mesh[7].AddRigidNode(-largo/2.0 ,0.0,   2.0*thck)



  
print("Piece Shell node count", len(shell_mesh.nodes))
# print("Shell Shell node count", len(sph1_mesh.nodes))

print("Shell node count: ", shell_mesh.node_count)

print("Sphere 1 node count", sph1_mesh.node_count)

if (double_sided):
    print("Sphere 2 node count:", sph2_mesh.node_count)

if (multi_tool):
    for k,sph in enumerate (sph_mesh):
        #print("extra tool k")
        print(f"extr {k} sphere node count: {sph.node_count}")



# print("Shell node count", len(shell_mesh.elnod))
# print("Shell node count", len(sph1_mesh.elnod))

model = Model()
model.set_Multi_tool(multi_tool_N)
#model.end_proc_time = end_time   #USED
model.set_end_time("movi_x0.inc") # extract end time of selected file or custom end time
model.double_sided = double_sided
print ("Model size: ", len(model.part))
shell = Part(1)
shell.AppendMesh(shell_mesh) 
model.vscal_fac = vscal_fac

model.mass_scal = mass_scal
model.ms_dtsize = ms_dtsize 
model.dampfac   = dampfac

bcpos = largo/2.0 - largo_supp

sph1_pt = Part(2)
sph1_pt.AppendMesh(sph1_mesh) 
sph1_pt.is_rigid = True
if (not tool_springs):
  sph1_pt.is_moving = True
sph1_pt.asignPropID(2)

if (double_sided):
  sph2_pt = Part(3)
  sph2_pt.AppendMesh(sph2_mesh) 
  sph2_pt.is_rigid = True
  if (not tool_springs):
    sph2_pt.is_moving = True
  sph2_pt.asignPropID(2)

#============================================================================
if (multi_tool):
    sph_pts = list()
    if double_sided:
        for i in range(multi_tool_N-2):
            print(f'add extra tool {i} to part {i+4}')
            sph_pts.append(Part(4+i))
            sph_pts[i].AppendMesh(sph_mesh[i]) 
            sph_pts[i].is_rigid = True
            if (not tool_springs):
              sph_pts[i].is_moving = True
            sph_pts[i].asignPropID(2)
    else:
        for i in range(multi_tool_N-1):
            print(f'add extra tool {i} to part {i+3}')
            sph_pts.append(Part(3+i))
            sph_pts[i].AppendMesh(sph_mesh[i]) 
            sph_pts[i].is_rigid = True
            if (not tool_springs):
              sph_pts[i].is_moving = True
            sph_pts[i].asignPropID(2)
        
else:
    i=-1 #Because if bottom tool increases 1
    
print ("After multi tools, part index i: ", i)
print ("========================================================")
#print ("tools added model size: ", len(model.part))
#============================================================================

model.AppendPart(shell) #FIRST PART TO ADD!

model.AppendPart(sph1_pt)

#CHANGED FOR CONTEMPLATING DOUBLE SIDEDsph_pt
#MAX LENGTH, not important if used or not
spring_toolnodes = [0] * 2 * multi_tool_N

#spring_toolnodes.append(model.tot_nod_count)
spring_toolnodes[0] = model.tot_nod_count

print ("Saving spring element node 1: ", model.tot_nod_count)

spring_toolnodes = [0] * 2 * multi_tool_N

#spring_toolnodes.append(model.tot_nod_count)
spring_toolnodes[0] = model.tot_nod_count
print ("Saving spring element node 1: ", model.tot_nod_count)

if (double_sided):
  model.AppendPart(sph2_pt)
  #spring_toolnodes.append(model.tot_nod_count)

i = 0
if (multi_tool):
    for sph_pt in sph_pts:
        model.AppendPart(sph_pt)
        print ("Append spring node ", model.tot_nod_count)
        #spring_toolnodes.append(model.tot_nod_count) #SPHERE NODE CENTER SPRING PARTS ARE AT THE END BUT WE're KEEPIN' NODE COUNT
        #SPRING NODES ARE SORTED AS ODD AND EVEN
        spring_toolnodes[1+i]=model.tot_nod_count 
        i+=1
        
if (cont_support):
  if double_sided:
      bot_tool_present=1
  else:
      bot_tool_present=0
  for sp in range (2*4):
    supp_part.append(Part(3+bot_tool_present+i+sp))
    print(f'add support {sp} to part {3+bot_tool_present+i+sp}, id {3+bot_tool_present+i+sp}')
    supp_part[sp].AppendMesh(supp_mesh[sp])
    supp_part[sp].is_rigid = True #REMEMBER LAST NODE OF THE PART IS THE PIVOT
    supp_part[sp].asignPropID(3)
    supp_part[sp].is_support = True
    print("support part length", len(supp_part))
    model.AppendPart(supp_part[sp])

if (not cont_support):
  model.AddNodeSetOutsideBoxXY(1000,Vector(-bcpos,-bcpos,0.0), Vector(bcpos,bcpos,0.0)) #id, v1, v2):

tool_springs_pts =[]
for i in range(2*multi_tool_N):
  tool_springs_pts.append(Part(1+(2*multi_tool_N)+8+i))
  print("Adding spring part id", 1+(2*multi_tool_N)+8+i)
  tool_springs_pts[i].is_rigid=False #do not print surf
      
if (tool_springs):
  print ("Adding Springs")
  
  driver_top.add_elem(spring_toolnodes[0],model.tot_nod_count+1) #NEXT NODE
  #driver_top.elnod[0][0] = - model.tot_nod_count+1
  #driver_top.add_elem(0,model.tot_nod_count+1) #NEXT NODE
  tool_springs_pts[0].AppendMesh(driver_top)
  tool_springs_pts[0].asignPropID(4)
  tool_springs_pts[0].elcon_renumber = False ### TO BE MODIFIED
  tool_springs_pts[0].is_moving = True
  #driver_top.add_elem()
  print ("Nodes: ", spring_toolnodes[0], "; ", model.tot_nod_count+1)
  #tool_springs_pts[0].mesh[0].add_elem(spring_toolnodes[0],model.tot_nod_count+1) #NEXT NODE
  model.AppendPart(tool_springs_pts[0])

  print ("Nodes: ", model.part[model.part_count-1].mesh[0].elnod[0][0], model.part[model.part_count-1].mesh[0].elnod[0][1])
    #driver_top.mesh[0].ini_node_id

  if double_sided:
    print ("Adding Bottom Springs")
    tool_springs_pts[multi_tool_N].AppendMesh(driver_bot)
    tool_springs_pts[multi_tool_N].asignPropID(4)
    tool_springs_pts[multi_tool_N].elcon_renumber = False ### TO BE MODIFIED
    tool_springs_pts[multi_tool_N].is_moving = True
    model.AppendPart(tool_springs_pts[multi_tool_N])


#FIRST UPPER TOOL
  if (multi_tool):
      #ALL SPRINGS FOR EVEN (TOP) AND TOP (BOTTOM)
      #HERE ONLY TOP
      #### TOP TOOLS
      for i in range(0,multi_tool_N-1):
        print ("i ", i)
        driver_top_mesh_mt[i].add_elem(spring_toolnodes[i+1],model.tot_nod_count+1)
        print ("Nodes: ", spring_toolnodes[i+1], "; ", model.tot_nod_count+1)
          #ADD HERE AN IF DOUBLE SIDED DRIVER BOT MESH WHICH IS IN A DIFFERENT NUMBER
        tool_springs_pts[i+1].AppendMesh(driver_top_mesh_mt[i])
        print ("mesh nodes ", tool_springs_pts[i+1].mesh[0].elnod[0][0], tool_springs_pts[i+1].mesh[0].elnod[0][1])
        print ("DRIVER TOP MESH  size ", driver_top_mesh_mt[i].elnod)
        tool_springs_pts[i+1].asignPropID(4)
        tool_springs_pts[i+1].elcon_renumber = False ### TO BE MODIFIED
        tool_springs_pts[i+1].is_moving = True
        #driver_top.add_elem()

        #tool_springs_pts[0].mesh[0].add_elem(spring_toolnodes[0],model.tot_nod_count+1) #NEXT NODE
        #ATENTION: PART MUST BE 4, because 104
        model.AppendPart(tool_springs_pts[i+1])



model.AppendMat(mat)
model.AppendProp(Prop(1,thck))

model.AppendProp(Prop(2,thck_rig))

model.AppendProp(Prop(3,thck_supp))

if (tool_springs):
  model.AppendProp(SpringProp(4,stiff_x,stiff_y,stiff_z))

#BALLS AND PLATE
inter_1 = Interface(2,1)
model.AppendInterface(inter_1)

if (double_sided):
  inter_2 = Interface(3,1)
  model.AppendInterface(inter_2)

#Multi - tool
if (multi_tool):
    inter_N=list()
    if double_sided:
        for index,i in enumerate(range(4,multi_tool_N+2)):
            print ("---------------------------------------------interface ", index, ", ", i)
            inter_N.append(Interface(i,1))
            model.AppendInterface(inter_N[index])
    else:
        for index,i in enumerate(range(3,multi_tool_N+2)):
            print ("---------------------------------------------interface ", index, ", ", i)
            inter_N.append(Interface(i,1))
            model.AppendInterface(inter_N[index])
else:
    i=0

#CHANGE TO ARRAY
if (cont_support):
  for sp in range (2*4):
    model.AppendInterface(Interface(sp+multi_tool_N+2,1))

model.cont_support = cont_support



#if (thermal):
#  model.part[0].mesh[0].print_segments = True #THERMAL SEGMENTS, RESERVED IDS TO PARTS

if (thermal):
  model.thermal = True

# THERMAL
#for e in range (model.part[0].mesh[0].elem_count):
  #lf = Function(0.0,.0,0)
  #model.AppendLoadFunction (lf)
# sphere_mesh = Sphere_Mesh(2,1.0, 10,1) #(self, id, radius, divisions, ininode):

# shell_mesh.printRadioss("radioss.rad")

# sphere_mesh.printRadioss("radioss.rad")

#IMPORTANTE: LA VELOCIDAD SE ASUME PARA RADIO CONSTANTE EN CADA VUELTAS
#CON LO CUAL EN LA REALIDAD DISMINUYE UN POCO
# def save(lin):

if (calc_path):
# f= open(textField.get(),"w+")
  # LA HERRAMIENTA INTERNA ESTA EN EL TOP, LA EXTERNA EN EL BOTTOM
  # PERO TOP Y BOTTOM CONFUNDE POR LAS INDENTACIONES
  fi_x = open("movi_x.inc","w")
  fi_y = open("movi_y.inc","w")
  fi_z = open("movi_z.inc","w")

  if (double_sided):  
    fo_x = open("movo_x.inc","w")
    fo_y = open("movo_y.inc","w")
    fo_z = open("movo_z.inc","w")

  fi_x.write("/FUNCT/1000001\nmovx\n")    
  fi_y.write("/FUNCT/1000002\nmovy\n")      
  fi_z.write("/FUNCT/1000003\nmovz\n")    

  if (double_sided):
    fo_x.write("/FUNCT/1000004\nmovx\n")    
    fo_y.write("/FUNCT/1000005\nmovy\n")      
    fo_z.write("/FUNCT/1000006\nmovz\n")
  
  t = 0.0
  r = r_i
  turn = 1
  
  z  = 0.0 
  # zo = -thck #ESTA HERRAMIENTA NO DESCIENDE (PARA EVITAR DEFORMACIONES IRREGULARES)
  # zi =  thck 
  zo = zi = 0
  vz = (thck + p_S) / t_ind # EN PRINCIPIO S EDESPLAZA SOLO LA INTERIOR 
  
  #####################INDENTACION ######################### 
  xi = r - p_D/2.0
  xo = r + p_D/2.0
  
  while (t < t_ind):    
    if (move_tool_to_inipos):
      xo -= x_init
      xi -= x_init

    zi -= vz * dt
    #HAY QUE VER SI ES NECESARIO ESCRIBIR X E Y PARA TODOS LOS TIEMPOS
    fi_x.write(writeFloatField(t,20,6) + writeFloatField(xi,20,6) + "\n")
    fi_y.write(writeFloatField(t,20,6) + writeFloatField(0.,20,6) + "\n")
    fi_z.write(writeFloatField(t,20,6) + writeFloatField(zi,20,6) + "\n")
    
    if (double_sided):
      fo_x.write(writeFloatField(t,20,6) + writeFloatField(xo,20,6) + "\n")
      fo_y.write(writeFloatField(t,20,6) + writeFloatField(0.,20,6) + "\n")
      fo_z.write(writeFloatField(t,20,6) + writeFloatField(zo,20,6) + "\n")
    
    # fo_x.write("%.6e, %.6e\n" % (t,xo))
    # fo_y.write("%.6e, %.6e\n" % (t,0.0))
    # fo_z.write("%.6e, %.6e\n" % (t,zo))  
    t +=dt 
 
  print("Final zi %.3e , zo %.3e \n" %(zi,zo))
  
  ######################## VUELTAS ##############################
  while (t < model.end_proc_time):
    t_ang = 2.0 * pi * r / tool_speed #Tiempo (incremento) de cada vuelta (ASUMIENDO RADIO CONSTANTE)
    print("Turn %d Turn Time %.3e Time %.3e Radius %.3e\n" %(turn, t_ang,t,r))
    t_vuelta = t + t_ang  #Tiempo de final de vuelta (TOTAL)
    t_0 = t               #Tiempo de comienzo de vuelta
    t_inc = 0.0           # t - t_0
    dz = dr               #CAMBIAR SEGUN GEOMETRIA
    vz = dz / t_ang
    while (t < t_vuelta): #VUELTAS  
      # print ("t_inc %.3e t_ang %.3e"%(t_inc,t_ang))
      xi = (r - p_D/2.0 + dr * t_inc/t_ang) *cos(2.0*pi*t_inc/t_ang)
      yi = (r - p_D/2.0 + dr * t_inc/t_ang) *sin(2.0*pi*t_inc/t_ang)
      zi -= vz * dt

      xo = (r + p_D/2.0 + dr * t_inc/t_ang) *cos(2.0*pi*t_inc/t_ang)
      yo = (r + p_D/2.0 + dr * t_inc/t_ang) *sin(2.0*pi*t_inc/t_ang)      
      zo -= vz * dt #CAMBIAR A DZ
      
      # print("zi %.3e , zo %.3e \n" %(zi,zo))
      # z -= t_inc/t_ang * dr # CAMBIAR A dz
      
      fi_x.write(writeFloatField(t,20,6) + writeFloatField(xi,20,6) + "\n")
      fi_y.write(writeFloatField(t,20,6) + writeFloatField(yi,20,6) + "\n")
      fi_z.write(writeFloatField(t,20,6) + writeFloatField(zi,20,6) + "\n")
      if (double_sided):
        fo_x.write(writeFloatField(t,20,6) + writeFloatField(xo,20,6) + "\n")
        fo_y.write(writeFloatField(t,20,6) + writeFloatField(yo,20,6) + "\n")
        fo_z.write(writeFloatField(t,20,6) + writeFloatField(zo,20,6) + "\n")
      
      # fo_x.write("%.6e, %.6e\n" % (t,xo))
      # fo_y.write("%.6e, %.6e\n" % (t,yo))
      # fo_z.write("%.6e, %.6e\n" % (t,zo))
      
      t_inc +=dt
      t += dt


#      if (thermal):
#        e = model.part[0].mesh[0].findNearestElem(xi,yi,zi)
#        flog.write ("TIME %f, pos: %.6e %.6e, Found %d\n" % (t, xi, yi, e ))
#        coord = str (model.part[0].mesh[0].elcenter[e].components)
#        flog.write ("baricenter: %s\n" %(coord))  
#        model.load_fnc[e].Append(t,1.0e6)
      
    r +=dr
    turn += 1    

  #SPRINGBACK
  
  fi_x.close;fi_y.close;fi_z.close
  if (double_sided):
    fo_x.close;fo_y.close;fo_z.close

              #filename, name, id, init_time, veloc):

f_upper_supp = Function(1000007+int(multi_tool_N*3),0.0,0.0) 
f_upper_supp.Append(model.end_proc_time, 0.0)
if (not supp_vel_ramp):
  f_upper_supp.Append(model.end_proc_time+1.0e-4, v_supp)
f_upper_supp.Append(model.end_proc_time+supp_rel_time, v_supp)
#f_upper_supp.Append(end_time+supp_rel_time+1.0e-4,  10.0*v_supp)
#f_upper_supp.Append(end_time+supp_rel_time+1.0e-4+dynrel_time,      10.0*v_supp)
f_upper_supp.Append(model.end_proc_time+supp_rel_time+dynrel_time,      10.0*v_supp)
model.supp_fnc.append(f_upper_supp)

tool_count = 1
if (double_sided):
  tool_count = 2

if (multi_tool):
    tool_count = multi_tool_N

for p in range(tool_count):
  model.part[p+1].temp_fnc.Append(1.0e-3, tool_temp)
  model.part[p+1].temp_fnc.Append(model.end_proc_time+supp_rel_time+dynrel_time, tool_temp)

#OLD; TEMP IN NODES  
#for e in range (model.part[0].mesh[0].elem_count):  
#  model.load_fnc[e].Append(1.0e3,0.0)



# for e in range (10):
  # # for f in range (len(load_function[e])):
  # for f in range (model.load_fnc[e].val_count):
    # print ("Load Fnction ", e, model.load_fnc[e].getVal(f))
  
model.set_end_time("movi_x0.inc")
model.printRadioss("test")

model.printEngine(1, model.end_proc_time,dtout, dtout_his)
model.printRelease(2, model.end_proc_time+supp_rel_time,dtout, dtout_his)
model.printDynRelax(3,model.end_proc_time+supp_rel_time+dynrel_time,dtout, dtout_his)
# #Si no se coloca lambda no funciona
# b = Button(window, text="Generate", width=10, command=lambda:save(linea_g))
# b.grid(column=3, row=10)
# #b.pack()

# window.title('Incremental Forming PATH Script')
# window.geometry("400x200+10+10")
# window.mainloop()
# Out:
# Reading Tool Path files to position tool
# data/MESIC_55_topToolTipPnts.csv, data/MESIC_55_topToolTipPnts.csv
# Top    Init X and Y positions:  0.0842448 -0.0
# [(1, 1), (2, 2), (3, 4)]
# 3
# 20 radial_elem_eigth
# x,y 0.07071067811865477 0
# x,y 0.03535533905932738 0.03535533905932738
# x,y 0 0.07071067811865477
# x,y -0.03535533905932738 0.03535533905932738
# x,y -0.07071067811865477 0
# x,y -0.03535533905932738 -0.03535533905932738
# x,y 0 -0.07071067811865477
# x,y 0.03535533905932738 -0.03535533905932738
# angle 0.0
# x,y 0.09499999999999999 0.0
# angle 0.7853981633974483
# x,y 0.06717514421272201 0.067175144212722
# angle 1.5707963267948966
# x,y 5.817072295949927e-18 0.09499999999999999
# angle 2.356194490192345
# x,y -0.067175144212722 0.06717514421272201
# angle 3.141592653589793
# x,y -0.09499999999999999 1.1634144591899854e-17
# angle 3.9269908169872414
# x,y -0.06717514421272203 -0.067175144212722
# angle 4.71238898038469
# x,y -1.7451216887849778e-17 -0.09499999999999999
# angle 5.497787143782138
# x,y 0.06717514421272198 -0.06717514421272203
# CURVE LINES  1 10 -33 -9
# CURVE LINES  2 11 -34 -10
# CURVE LINES  3 12 -35 -11
# CURVE LINES  4 13 -36 -12
# CURVE LINES  5 14 -37 -13
# CURVE LINES  6 15 -38 -14
# CURVE LINES  7 16 -39 -15
# CURVE LINES  8 9 -40 -16
# CURVE LINES  33 18 -41 -17
# CURVE LINES  34 19 -42 -18
# CURVE LINES  35 20 -43 -19
# CURVE LINES  36 21 -44 -20
# CURVE LINES  37 22 -45 -21
# CURVE LINES  38 23 -46 -22
# CURVE LINES  39 24 -47 -23
# CURVE LINES  40 17 -48 -24
# EXTERNAL LOOPS
# CURVE LINES  41 26 -49 -25
# CURVE LINES  42 27 -50 -26
# CURVE LINES  43 28 -51 -27
# CURVE LINES  44 29 -52 -28
# CURVE LINES  45 30 -53 -29
# CURVE LINES  46 31 -54 -30
# CURVE LINES  47 32 -55 -31
# CURVE LINES  48 25 -56 -32
# Node count  10429
# Node 1: [0. 0. 0.]
# Node 2: [0.07071068 0.         0.        ]
# Node 3: [0.03535534 0.03535534 0.        ]
# Node 4: [0.         0.07071068 0.        ]
# Node 5: [-0.03535534  0.03535534  0.        ]
# Node 6: [-0.07071068  0.          0.        ]
# Node 7: [-0.03535534 -0.03535534  0.        ]
# Node 8: [ 0.         -0.07071068  0.        ]
# Node 9: [ 0.03535534 -0.03535534  0.        ]
# Node 10: [0.095 0.    0.   ]
# Node 11: [0.06717514 0.06717514 0.        ]
# Node 12: [5.8170723e-18 9.5000000e-02 0.0000000e+00]
# Node 13: [-0.06717514  0.06717514  0.        ]
# Node 14: [-9.50000000e-02  1.16341446e-17  0.00000000e+00]
# Node 15: [-0.06717514 -0.06717514  0.        ]
# Node 16: [-1.74512169e-17 -9.50000000e-02  0.00000000e+00]
# Node 17: [ 0.06717514 -0.06717514  0.        ]
# Node 18: [0.18 0.   0.  ]
# Node 19: [0.12727922 0.12727922 0.        ]
# Node 20: [1.10218212e-17 1.80000000e-01 0.00000000e+00]
# Node 21: [-0.12727922  0.12727922  0.        ]
# Node 22: [-1.80000000e-01  2.20436424e-17  0.00000000e+00]
# Node 23: [-0.12727922 -0.12727922  0.        ]
# Node 24: [-3.30654636e-17 -1.80000000e-01  0.00000000e+00]
# Node 25: [ 0.12727922 -0.12727922  0.        ]
# Node 26: [0.22 0.   0.  ]
# Node 27: [0.22 0.22 0.  ]
# Node 28: [0.   0.22 0.  ]
# Node 29: [-0.22  0.22  0.  ]
# Node 30: [-0.22  0.    0.  ]
# Node 31: [-0.22 -0.22  0.  ]
# Node 32: [ 0.   -0.22  0.  ]
# Node 33: [ 0.22 -0.22  0.  ]
# Node 34: [0.06884987 0.00186081 0.        ]
# Node 35: [0.06698906 0.00372161 0.        ]
# Node 36: [0.06512826 0.00558242 0.        ]
# Node 37: [0.06326745 0.00744323 0.        ]
# Node 38: [0.06140664 0.00930404 0.        ]
# Node 39: [0.05954583 0.01116484 0.        ]
# Node 40: [0.05768503 0.01302565 0.        ]
# Node 41: [0.05582422 0.01488646 0.        ]
# Node 42: [0.05396341 0.01674727 0.        ]
# Node 43: [0.0521026  0.01860807 0.        ]
# Node 44: [0.0502418  0.02046888 0.        ]
# Node 45: [0.04838099 0.02232969 0.        ]
# Node 46: [0.04652018 0.0241905  0.        ]
# Node 47: [0.04465938 0.0260513  0.        ]
# Node 48: [0.04279857 0.02791211 0.        ]
# Node 49: [0.04093776 0.02977292 0.        ]
# Node 50: [0.03907695 0.03163372 0.        ]
# Node 51: [0.03721615 0.03349453 0.        ]
# Node 52: [0.03349453 0.03721615 0.        ]
# Node 53: [0.03163372 0.03907695 0.        ]
# Node 54: [0.02977292 0.04093776 0.        ]
# Node 55: [0.02791211 0.04279857 0.        ]
# Node 56: [0.0260513  0.04465938 0.        ]
# Node 57: [0.0241905  0.04652018 0.        ]
# Node 58: [0.02232969 0.04838099 0.        ]
# Node 59: [0.02046888 0.0502418  0.        ]
# Node 60: [0.01860807 0.0521026  0.        ]
# Node 61: [0.01674727 0.05396341 0.        ]
# Node 62: [0.01488646 0.05582422 0.        ]
# Node 63: [0.01302565 0.05768503 0.        ]
# Node 64: [0.01116484 0.05954583 0.        ]
# Node 65: [0.00930404 0.06140664 0.        ]
# Node 66: [0.00744323 0.06326745 0.        ]
# Node 67: [0.00558242 0.06512826 0.        ]
# Node 68: [0.00372161 0.06698906 0.        ]
# Node 69: [0.00186081 0.06884987 0.        ]
# Node 70: [-0.00186081  0.06884987  0.        ]
# Node 71: [-0.00372161  0.06698906  0.        ]
# Node 72: [-0.00558242  0.06512826  0.        ]
# Node 73: [-0.00744323  0.06326745  0.        ]
# Node 74: [-0.00930404  0.06140664  0.        ]
# Node 75: [-0.01116484  0.05954583  0.        ]
# Node 76: [-0.01302565  0.05768503  0.        ]
# Node 77: [-0.01488646  0.05582422  0.        ]
# Node 78: [-0.01674727  0.05396341  0.        ]
# Node 79: [-0.01860807  0.0521026   0.        ]
# Node 80: [-0.02046888  0.0502418   0.        ]
# Node 81: [-0.02232969  0.04838099  0.        ]
# Node 139: [-0.00558242 -0.06512826  0.        ]
# Node 140: [-0.00372161 -0.06698906  0.        ]
# Node 141: [-0.00186081 -0.06884987  0.        ]
# Node 142: [ 0.00186081 -0.06884987  0.        ]
# Node 143: [ 0.00372161 -0.06698906  0.        ]
# Node 144: [ 0.00558242 -0.06512826  0.        ]
# Node 145: [ 0.00744323 -0.06326745  0.        ]
# Node 146: [ 0.00930404 -0.06140664  0.        ]
# Node 147: [ 0.01116484 -0.05954583  0.        ]
# Node 148: [ 0.01302565 -0.05768503  0.        ]
# Node 149: [ 0.01488646 -0.05582422  0.        ]
# Node 150: [ 0.01674727 -0.05396341  0.        ]
# Node 151: [ 0.01860807 -0.0521026   0.        ]
# Node 152: [ 0.02046888 -0.0502418   0.        ]
# Node 153: [ 0.02232969 -0.04838099  0.        ]
# Node 154: [ 0.0241905  -0.04652018  0.        ]
# Node 155: [ 0.0260513  -0.04465938  0.        ]
# Node 156: [ 0.02791211 -0.04279857  0.        ]
# Node 157: [ 0.02977292 -0.04093776  0.        ]
# Node 158: [ 0.03163372 -0.03907695  0.        ]
# Node 159: [ 0.03349453 -0.03721615  0.        ]
# Node 160: [ 0.03721615 -0.03349453  0.        ]
# Node 161: [ 0.03907695 -0.03163372  0.        ]
# Node 162: [ 0.04093776 -0.02977292  0.        ]
# Node 163: [ 0.04279857 -0.02791211  0.        ]
# Node 164: [ 0.04465938 -0.0260513   0.        ]
# Node 165: [ 0.04652018 -0.0241905   0.        ]
# Node 166: [ 0.04838099 -0.02232969  0.        ]
# Node 167: [ 0.0502418  -0.02046888  0.        ]
# Node 168: [ 0.0521026  -0.01860807  0.        ]
# Node 169: [ 0.05396341 -0.01674727  0.        ]
# Node 170: [ 0.05582422 -0.01488646  0.        ]
# Node 171: [ 0.05768503 -0.01302565  0.        ]
# Node 172: [ 0.05954583 -0.01116484  0.        ]
# Node 173: [ 0.06140664 -0.00930404  0.        ]
# Node 174: [ 0.06326745 -0.00744323  0.        ]
# Node 175: [ 0.06512826 -0.00558242  0.        ]
# Node 176: [ 0.06698906 -0.00372161  0.        ]
# Node 177: [ 0.06884987 -0.00186081  0.        ]
# Node 178: [0.07198906 0.         0.        ]
# Node 179: [0.07326745 0.         0.        ]
# Node 180: [0.07454583 0.         0.        ]
# Node 181: [0.07582422 0.         0.        ]
# Node 182: [0.0771026 0.        0.       ]
# Node 183: [0.07838099 0.         0.        ]
# Node 184: [0.07965938 0.         0.        ]
# Node 185: [0.08093776 0.         0.        ]
# Node 186: [0.08221615 0.         0.        ]
# Node 187: [0.08349453 0.         0.        ]
# Node 188: [0.08477292 0.         0.        ]
# Node 189: [0.0860513 0.        0.       ]
# Node 190: [0.08732969 0.         0.        ]
# Node 191: [0.08860807 0.         0.        ]
# Node 192: [0.08988646 0.         0.        ]
# Node 193: [0.09116484 0.         0.        ]
# Node 194: [0.09244323 0.         0.        ]
# Node 195: [0.09372161 0.         0.        ]
# Node 196: [0.03703007 0.03703007 0.        ]
# Node 197: [0.03870479 0.03870479 0.        ]
# Node 604: [ 0.19071975 -0.19071975  0.        ]
# Node 605: [ 0.19559979 -0.19559979  0.        ]
# Node 606: [ 0.20047984 -0.20047984  0.        ]
# Node 607: [ 0.20535988 -0.20535988  0.        ]
# Node 608: [ 0.21023992 -0.21023992  0.        ]
# Node 609: [ 0.21511996 -0.21511996  0.        ]
# Node 610: [0.09491885 0.00392587 0.        ]
# Node 611: [0.09467553 0.00784504 0.        ]
# Node 612: [0.09427046 0.0117508  0.        ]
# Node 613: [0.09370432 0.01563649 0.        ]
# Node 614: [0.0929781  0.01949546 0.        ]
# Node 615: [0.09209303 0.02332112 0.        ]
# Node 616: [0.09105061 0.02710694 0.        ]
# Node 617: [0.08985264 0.03084645 0.        ]
# Node 618: [0.08850115 0.03453326 0.        ]
# Node 619: [0.08699847 0.03816107 0.        ]
# Node 620: [0.08534714 0.04172368 0.        ]
# Node 621: [0.08355001 0.045215   0.        ]
# Node 622: [0.08161013 0.04862908 0.        ]
# Node 623: [0.07953082 0.05196008 0.        ]
# Node 624: [0.07731563 0.0552023  0.        ]
# Node 625: [0.07496835 0.05835021 0.        ]
# Node 626: [0.07249299 0.06139843 0.        ]
# Node 627: [0.06989377 0.06434175 0.        ]
# Node 628: [0.06434175 0.06989377 0.        ]
# Node 629: [0.06139843 0.07249299 0.        ]
# Node 630: [0.05835021 0.07496835 0.        ]
# Node 631: [0.0552023  0.07731563 0.        ]
# Node 632: [0.05196007 0.07953082 0.        ]
# Node 633: [0.04862908 0.08161013 0.        ]
# Node 634: [0.045215   0.08355001 0.        ]
# Node 635: [0.04172368 0.08534714 0.        ]
# Node 636: [0.03816107 0.08699847 0.        ]
# Node 637: [0.03453326 0.08850115 0.        ]
# Node 638: [0.03084645 0.08985264 0.        ]
# Node 639: [0.02710694 0.09105061 0.        ]
# Node 640: [0.02332112 0.09209303 0.        ]
# Node 641: [0.01949546 0.0929781  0.        ]
# Node 642: [0.01563649 0.09370432 0.        ]
# Node 643: [0.0117508  0.09427046 0.        ]
# Node 644: [0.00784504 0.09467553 0.        ]
# Node 645: [0.00392587 0.09491885 0.        ]
# Node 646: [-0.00392587  0.09491885  0.        ]
# Node 647: [-0.00784504  0.09467553  0.        ]
# Node 648: [-0.0117508   0.09427046  0.        ]
# Node 649: [-0.01563649  0.09370432  0.        ]
# Node 650: [-0.01949546  0.0929781   0.        ]
# Node 651: [-0.02332112  0.09209303  0.        ]
# Node 652: [-0.02710694  0.09105061  0.        ]
# Node 653: [-0.03084645  0.08985264  0.        ]
# Node 654: [-0.03453326  0.08850115  0.        ]
# Node 655: [-0.03816107  0.08699847  0.        ]
# Node 656: [-0.04172368  0.08534714  0.        ]
# Node 657: [-0.045215    0.08355001  0.        ]
# Node 658: [-0.04862908  0.08161013  0.        ]
# Node 659: [-0.05196008  0.07953082  0.        ]
# Node 660: [-0.0552023   0.07731563  0.        ]
# Node 661: [-0.05835021  0.07496835  0.        ]
# Node 662: [-0.06139843  0.07249299  0.        ]
# Node 720: [ 0.0117508  -0.09427046  0.        ]
# Node 721: [ 0.01563649 -0.09370432  0.        ]
# Node 722: [ 0.01949546 -0.0929781   0.        ]
# Node 723: [ 0.02332112 -0.09209303  0.        ]
# Node 724: [ 0.02710694 -0.09105061  0.        ]
# Node 725: [ 0.03084645 -0.08985264  0.        ]
# Node 726: [ 0.03453326 -0.08850115  0.        ]
# Node 727: [ 0.03816107 -0.08699847  0.        ]
# Node 728: [ 0.04172368 -0.08534714  0.        ]
# Node 729: [ 0.045215   -0.08355001  0.        ]
# Node 730: [ 0.04862908 -0.08161013  0.        ]
# Node 731: [ 0.05196008 -0.07953082  0.        ]
# Node 732: [ 0.0552023  -0.07731563  0.        ]
# Node 733: [ 0.05835021 -0.07496835  0.        ]
# Node 734: [ 0.06139843 -0.07249299  0.        ]
# Node 735: [ 0.06434175 -0.06989377  0.        ]
# Node 736: [ 0.06989377 -0.06434175  0.        ]
# Node 737: [ 0.07249299 -0.06139843  0.        ]
# Node 738: [ 0.07496835 -0.05835021  0.        ]
# Node 739: [ 0.07731563 -0.0552023   0.        ]
# Node 740: [ 0.07953082 -0.05196007  0.        ]
# Node 741: [ 0.08161013 -0.04862908  0.        ]
# Node 742: [ 0.08355001 -0.045215    0.        ]
# Node 743: [ 0.08534714 -0.04172368  0.        ]
# Node 744: [ 0.08699847 -0.03816107  0.        ]
# Node 745: [ 0.08850115 -0.03453326  0.        ]
# Node 746: [ 0.08985264 -0.03084645  0.        ]
# Node 747: [ 0.09105061 -0.02710694  0.        ]
# Node 748: [ 0.09209303 -0.02332112  0.        ]
# Node 749: [ 0.0929781  -0.01949546  0.        ]
# Node 750: [ 0.09370432 -0.01563649  0.        ]
# Node 751: [ 0.09427046 -0.0117508   0.        ]
# Node 752: [ 0.09467553 -0.00784504  0.        ]
# Node 753: [ 0.09491885 -0.00392587  0.        ]
# Node 754: [0.17984624 0.0074385  0.        ]
# Node 755: [0.17938521 0.01486428 0.        ]
# Node 756: [0.1786177  0.02226467 0.        ]
# Node 757: [0.17754503 0.02962703 0.        ]
# Node 758: [0.17616903 0.03693876 0.        ]
# Node 759: [0.17449205 0.04418739 0.        ]
# Node 760: [0.17251695 0.05136052 0.        ]
# Node 761: [0.1702471 0.0584459 0.       ]
# Node 762: [0.1676864  0.06543143 0.        ]
# Node 763: [0.1648392  0.07230518 0.        ]
# Node 764: [0.16171038 0.07905539 0.        ]
# Node 765: [0.15830528 0.08567053 0.        ]
# Node 766: [0.15462971 0.09213931 0.        ]
# Node 767: [0.15068997 0.09845067 0.        ]
# Node 768: [0.14649277 0.10459383 0.        ]
# Node 769: [0.14204529 0.11055829 0.        ]
# Node 770: [0.13735513 0.11633386 0.        ]
# Node 771: [0.1324303  0.12191068 0.        ]
# Node 772: [0.12191068 0.1324303  0.        ]
# Node 773: [0.11633386 0.13735513 0.        ]
# Node 774: [0.11055829 0.14204529 0.        ]
# Node 775: [0.10459383 0.14649277 0.        ]
# Node 776: [0.09845067 0.15068997 0.        ]
# Node 835: [-0.1648392  -0.07230518  0.        ]
# Node 836: [-0.16171038 -0.07905539  0.        ]
# Node 837: [-0.15830528 -0.08567053  0.        ]
# Node 838: [-0.15462971 -0.09213931  0.        ]
# Node 839: [-0.15068997 -0.09845067  0.        ]
# Node 840: [-0.14649277 -0.10459383  0.        ]
# Node 841: [-0.14204529 -0.11055829  0.        ]
# Node 842: [-0.13735513 -0.11633386  0.        ]
# Node 843: [-0.1324303  -0.12191068  0.        ]
# Node 844: [-0.12191068 -0.1324303   0.        ]
# Node 845: [-0.11633386 -0.13735513  0.        ]
# Node 846: [-0.11055829 -0.14204529  0.        ]
# Node 847: [-0.10459383 -0.14649277  0.        ]
# Node 848: [-0.09845067 -0.15068997  0.        ]
# Node 849: [-0.09213931 -0.15462971  0.        ]
# Node 850: [-0.08567053 -0.15830528  0.        ]
# Node 851: [-0.07905539 -0.16171038  0.        ]
# Node 852: [-0.07230518 -0.1648392   0.        ]
# Node 853: [-0.06543143 -0.1676864   0.        ]
# Node 854: [-0.0584459 -0.1702471  0.       ]
# Node 855: [-0.05136052 -0.17251695  0.        ]
# Node 856: [-0.04418739 -0.17449205  0.        ]
# Node 857: [-0.03693876 -0.17616903  0.        ]
# Node 858: [-0.02962703 -0.17754503  0.        ]
# Node 859: [-0.02226467 -0.1786177   0.        ]
# Node 860: [-0.01486428 -0.17938521  0.        ]
# Node 861: [-0.0074385  -0.17984624  0.        ]
# Node 862: [ 0.0074385  -0.17984624  0.        ]
# Node 863: [ 0.01486428 -0.17938521  0.        ]
# Node 864: [ 0.02226467 -0.1786177   0.        ]
# Node 865: [ 0.02962703 -0.17754503  0.        ]
# Node 866: [ 0.03693876 -0.17616903  0.        ]
# Node 867: [ 0.04418739 -0.17449205  0.        ]
# Node 868: [ 0.05136052 -0.17251695  0.        ]
# Node 869: [ 0.0584459 -0.1702471  0.       ]
# Node 870: [ 0.06543143 -0.1676864   0.        ]
# Node 871: [ 0.07230518 -0.1648392   0.        ]
# Node 872: [ 0.07905539 -0.16171038  0.        ]
# Node 873: [ 0.08567053 -0.15830528  0.        ]
# Node 874: [ 0.09213931 -0.15462971  0.        ]
# Node 875: [ 0.09845067 -0.15068997  0.        ]
# Node 876: [ 0.10459383 -0.14649277  0.        ]
# Node 877: [ 0.11055829 -0.14204529  0.        ]
# Node 878: [ 0.11633386 -0.13735513  0.        ]
# Node 879: [ 0.12191068 -0.1324303   0.        ]
# Node 880: [ 0.1324303  -0.12191068  0.        ]
# Node 881: [ 0.13735513 -0.11633386  0.        ]
# Node 882: [ 0.14204529 -0.11055829  0.        ]
# Node 883: [ 0.14649277 -0.10459383  0.        ]
# Node 884: [ 0.15068997 -0.09845067  0.        ]
# Node 885: [ 0.15462971 -0.09213931  0.        ]
# Node 886: [ 0.15830528 -0.08567053  0.        ]
# Node 887: [ 0.16171038 -0.07905539  0.        ]
# Node 888: [ 0.1648392  -0.07230518  0.        ]
# Node 889: [ 0.1676864  -0.06543143  0.        ]
# Node 890: [ 0.1702471 -0.0584459  0.       ]
# Node 891: [ 0.17251695 -0.05136052  0.        ]
# Node 892: [ 0.17449205 -0.04418739  0.        ]
# Node 893: [ 0.17616903 -0.03693876  0.        ]
# Node 894: [ 0.17754503 -0.02962703  0.        ]
# Node 895: [ 0.1786177  -0.02226467  0.        ]
# Node 896: [ 0.17938521 -0.01486428  0.        ]
# Node 897: [ 0.17984624 -0.0074385   0.        ]
# Node 898: [0.22       0.01157895 0.        ]
# Node 899: [0.22       0.02315789 0.        ]
# Node 900: [0.22       0.03473684 0.        ]
# Node 901: [0.22       0.04631579 0.        ]
# Node 902: [0.22       0.05789474 0.        ]
# Node 903: [0.22       0.06947368 0.        ]
# Node 904: [0.22       0.08105263 0.        ]
# Node 905: [0.22       0.09263158 0.        ]
# Node 906: [0.22       0.10421053 0.        ]
# Node 907: [0.22       0.11578947 0.        ]
# Node 908: [0.22       0.12736842 0.        ]
# Node 909: [0.22       0.13894737 0.        ]
# Node 910: [0.22       0.15052632 0.        ]
# Node 911: [0.22       0.16210526 0.        ]
# Node 912: [0.22       0.17368421 0.        ]
# Node 913: [0.22       0.18526316 0.        ]
# Node 914: [0.22       0.19684211 0.        ]
# Node 915: [0.22       0.20842105 0.        ]
# Node 916: [0.20842105 0.22       0.        ]
# Node 917: [0.19684211 0.22       0.        ]
# Node 918: [0.18526316 0.22       0.        ]
# Node 919: [0.17368421 0.22       0.        ]
# Node 920: [0.16210526 0.22       0.        ]
# Node 921: [0.15052632 0.22       0.        ]
# Node 922: [0.13894737 0.22       0.        ]
# Node 923: [0.12736842 0.22       0.        ]
# Node 924: [0.11578947 0.22       0.        ]
# Node 925: [0.10421053 0.22       0.        ]
# Node 926: [0.09263158 0.22       0.        ]
# Node 927: [0.08105263 0.22       0.        ]
# Node 928: [0.06947368 0.22       0.        ]
# Node 929: [0.05789474 0.22       0.        ]
# Node 930: [0.04631579 0.22       0.        ]
# Node 931: [0.03473684 0.22       0.        ]
# Node 932: [0.02315789 0.22       0.        ]
# Node 933: [0.01157895 0.22       0.        ]
# Node 934: [-0.01157895  0.22        0.        ]
# Node 935: [-0.02315789  0.22        0.        ]
# Node 936: [-0.03473684  0.22        0.        ]
# Node 937: [-0.04631579  0.22        0.        ]
# Node 938: [-0.05789474  0.22        0.        ]
# Node 939: [-0.06947368  0.22        0.        ]
# Node 940: [-0.08105263  0.22        0.        ]
# Node 941: [-0.09263158  0.22        0.        ]
# Node 942: [-0.10421053  0.22        0.        ]
# Node 943: [-0.11578947  0.22        0.        ]
# Node 944: [-0.12736842  0.22        0.        ]
# Node 945: [-0.13894737  0.22        0.        ]
# Node 946: [-0.15052632  0.22        0.        ]
# Node 947: [-0.16210526  0.22        0.        ]
# Node 948: [-0.17368421  0.22        0.        ]
# Node 949: [-0.18526316  0.22        0.        ]
# Node 950: [-0.19684211  0.22        0.        ]
# Node 951: [-0.20842105  0.22        0.        ]
# ...
# Quad element 12859: Nodes: [10167 10185 10186 10168]
# Quad element 12860: Nodes: [10168 10186 10187 10169]
# Quad element 12861: Nodes: [10169 10187 10188 10170]
# Quad element 12862: Nodes: [10170 10188 10189 10171]
# Quad element 12863: Nodes: [10171 10189 10190 10172]
# Quad element 12864: Nodes: [10172 10190 10191 10173]
# Quad element 12865: Nodes: [10173 10191 10192 10174]
# Quad element 12866: Nodes: [10174 10192 10193 10175]
# Quad element 12867: Nodes: [10175 10193 10194 10176]
# Quad element 12868: Nodes: [10176 10194 10195 10177]
# Quad element 12869: Nodes: [10177 10195  1028  1027]
# Quad element 12870: Nodes: [  884   885 10196 10178]
# Quad element 12871: Nodes: [10178 10196 10197 10179]
# Quad element 12872: Nodes: [10179 10197 10198 10180]
# Quad element 12873: Nodes: [10180 10198 10199 10181]
# Quad element 12874: Nodes: [10181 10199 10200 10182]
# Quad element 12875: Nodes: [10182 10200 10201 10183]
# Quad element 12876: Nodes: [10183 10201 10202 10184]
# Quad element 12877: Nodes: [10184 10202 10203 10185]
# Quad element 12878: Nodes: [10185 10203 10204 10186]
# Quad element 12879: Nodes: [10186 10204 10205 10187]
# Quad element 12880: Nodes: [10187 10205 10206 10188]
# Quad element 12881: Nodes: [10188 10206 10207 10189]
# Quad element 12882: Nodes: [10189 10207 10208 10190]
# Quad element 12883: Nodes: [10190 10208 10209 10191]
# Quad element 12884: Nodes: [10191 10209 10210 10192]
# Quad element 12885: Nodes: [10192 10210 10211 10193]
# Quad element 12886: Nodes: [10193 10211 10212 10194]
# Quad element 12887: Nodes: [10194 10212 10213 10195]
# Quad element 12888: Nodes: [10195 10213  1029  1028]
# Quad element 12889: Nodes: [  885   886 10214 10196]
# Quad element 12890: Nodes: [10196 10214 10215 10197]
# Quad element 12891: Nodes: [10197 10215 10216 10198]
# Quad element 12892: Nodes: [10198 10216 10217 10199]
# Quad element 12893: Nodes: [10199 10217 10218 10200]
# Quad element 12894: Nodes: [10200 10218 10219 10201]
# Quad element 12895: Nodes: [10201 10219 10220 10202]
# Quad element 12896: Nodes: [10202 10220 10221 10203]
# Quad element 12897: Nodes: [10203 10221 10222 10204]
# Quad element 12898: Nodes: [10204 10222 10223 10205]
# Quad element 12899: Nodes: [10205 10223 10224 10206]
# Quad element 12900: Nodes: [10206 10224 10225 10207]
# Quad element 12901: Nodes: [10207 10225 10226 10208]
# Quad element 12902: Nodes: [10208 10226 10227 10209]
# Quad element 12903: Nodes: [10209 10227 10228 10210]
# Quad element 12904: Nodes: [10210 10228 10229 10211]
# Quad element 12905: Nodes: [10211 10229 10230 10212]
# Quad element 12906: Nodes: [10212 10230 10231 10213]
# Quad element 12907: Nodes: [10213 10231  1030  1029]
# Quad element 12908: Nodes: [  886   887 10232 10214]
# Quad element 12909: Nodes: [10214 10232 10233 10215]
# Quad element 12910: Nodes: [10215 10233 10234 10216]
# Quad element 12911: Nodes: [10216 10234 10235 10217]
# Quad element 12912: Nodes: [10217 10235 10236 10218]
# Quad element 12913: Nodes: [10218 10236 10237 10219]
# Quad element 12914: Nodes: [10219 10237 10238 10220]
# Quad element 12915: Nodes: [10220 10238 10239 10221]
# Quad element 12916: Nodes: [10221 10239 10240 10222]
# Quad element 12917: Nodes: [10222 10240 10241 10223]
# Quad element 12918: Nodes: [10223 10241 10242 10224]
# Quad element 12919: Nodes: [10224 10242 10243 10225]
# Quad element 12920: Nodes: [10225 10243 10244 10226]
# Quad element 12921: Nodes: [10226 10244 10245 10227]
# Quad element 12922: Nodes: [10227 10245 10246 10228]
# Quad element 12923: Nodes: [10228 10246 10247 10229]
# Quad element 12924: Nodes: [10229 10247 10248 10230]
# Quad element 12925: Nodes: [10230 10248 10249 10231]
# Quad element 12926: Nodes: [10231 10249  1031  1030]
# Quad element 12927: Nodes: [  887   888 10250 10232]
# Quad element 12928: Nodes: [10232 10250 10251 10233]
# Quad element 12929: Nodes: [10233 10251 10252 10234]
# Quad element 12930: Nodes: [10234 10252 10253 10235]
# Quad element 12931: Nodes: [10235 10253 10254 10236]
# Quad element 12932: Nodes: [10236 10254 10255 10237]
# Quad element 12933: Nodes: [10237 10255 10256 10238]
# Quad element 12934: Nodes: [10238 10256 10257 10239]
# Quad element 12935: Nodes: [10239 10257 10258 10240]
# Quad element 12936: Nodes: [10240 10258 10259 10241]
# Quad element 12937: Nodes: [10241 10259 10260 10242]
# Quad element 12938: Nodes: [10242 10260 10261 10243]
# Quad element 12939: Nodes: [10243 10261 10262 10244]
# Quad element 12940: Nodes: [10244 10262 10263 10245]
# Quad element 12941: Nodes: [10245 10263 10264 10246]
# Quad element 12942: Nodes: [10246 10264 10265 10247]
# Quad element 12943: Nodes: [10247 10265 10266 10248]
# Quad element 12944: Nodes: [10248 10266 10267 10249]
# Quad element 12945: Nodes: [10249 10267  1032  1031]
# Quad element 12946: Nodes: [  888   889 10268 10250]
# Quad element 12947: Nodes: [10250 10268 10269 10251]
# Quad element 12948: Nodes: [10251 10269 10270 10252]
# Quad element 12949: Nodes: [10252 10270 10271 10253]
# Quad element 12950: Nodes: [10253 10271 10272 10254]
# Quad element 12951: Nodes: [10254 10272 10273 10255]
# Quad element 12952: Nodes: [10255 10273 10274 10256]
# Quad element 12953: Nodes: [10256 10274 10275 10257]
# Quad element 12954: Nodes: [10257 10275 10276 10258]
# Quad element 12955: Nodes: [10258 10276 10277 10259]
# Quad element 12956: Nodes: [10259 10277 10278 10260]
# Quad element 12957: Nodes: [10260 10278 10279 10261]
# Quad element 12958: Nodes: [10261 10279 10280 10262]
# Quad element 12959: Nodes: [10262 10280 10281 10263]
# Quad element 12960: Nodes: [10263 10281 10282 10264]
# Quad element 12961: Nodes: [10264 10282 10283 10265]
# Quad element 12962: Nodes: [10265 10283 10284 10266]
# Quad element 12963: Nodes: [10266 10284 10285 10267]
# Quad element 12964: Nodes: [10267 10285  1033  1032]
# Quad element 12965: Nodes: [  889   890 10286 10268]
# Quad element 12966: Nodes: [10268 10286 10287 10269]
# Quad element 12967: Nodes: [10269 10287 10288 10270]
# Quad element 12968: Nodes: [10270 10288 10289 10271]
# Quad element 12969: Nodes: [10271 10289 10290 10272]
# Quad element 12970: Nodes: [10272 10290 10291 10273]
# Quad element 12971: Nodes: [10273 10291 10292 10274]
# Quad element 12972: Nodes: [10274 10292 10293 10275]
# Quad element 12973: Nodes: [10275 10293 10294 10276]
# Quad element 12974: Nodes: [10276 10294 10295 10277]
# Quad element 12975: Nodes: [10277 10295 10296 10278]
# Quad element 12976: Nodes: [10278 10296 10297 10279]
# Quad element 12977: Nodes: [10279 10297 10298 10280]
# Quad element 12978: Nodes: [10280 10298 10299 10281]
# Quad element 12979: Nodes: [10281 10299 10300 10282]
# Quad element 12980: Nodes: [10282 10300 10301 10283]
# Quad element 12981: Nodes: [10283 10301 10302 10284]
# Quad element 12982: Nodes: [10284 10302 10303 10285]
# Quad element 12983: Nodes: [10285 10303  1034  1033]
# Quad element 12984: Nodes: [  890   891 10304 10286]
# Quad element 12985: Nodes: [10286 10304 10305 10287]
# Quad element 12986: Nodes: [10287 10305 10306 10288]
# Quad element 12987: Nodes: [10288 10306 10307 10289]
# Quad element 12988: Nodes: [10289 10307 10308 10290]
# Quad element 12989: Nodes: [10290 10308 10309 10291]
# Quad element 12990: Nodes: [10291 10309 10310 10292]
# Quad element 12991: Nodes: [10292 10310 10311 10293]
# Quad element 12992: Nodes: [10293 10311 10312 10294]
# Quad element 12993: Nodes: [10294 10312 10313 10295]
# Quad element 12994: Nodes: [10295 10313 10314 10296]
# Quad element 12995: Nodes: [10296 10314 10315 10297]
# Quad element 12996: Nodes: [10297 10315 10316 10298]
# Quad element 12997: Nodes: [10298 10316 10317 10299]
# Quad element 12998: Nodes: [10299 10317 10318 10300]
# Quad element 12999: Nodes: [10300 10318 10319 10301]
# Quad element 13000: Nodes: [10301 10319 10320 10302]
# Quad element 13001: Nodes: [10302 10320 10321 10303]
# Quad element 13002: Nodes: [10303 10321  1035  1034]
# Quad element 13003: Nodes: [  891   892 10322 10304]
# Quad element 13004: Nodes: [10304 10322 10323 10305]
# Quad element 13005: Nodes: [10305 10323 10324 10306]
# Quad element 13006: Nodes: [10306 10324 10325 10307]
# Quad element 13007: Nodes: [10307 10325 10326 10308]
# Quad element 13008: Nodes: [10308 10326 10327 10309]
# Quad element 13009: Nodes: [10309 10327 10328 10310]
# Quad element 13010: Nodes: [10310 10328 10329 10311]
# Quad element 13011: Nodes: [10311 10329 10330 10312]
# Quad element 13012: Nodes: [10312 10330 10331 10313]
# Quad element 13013: Nodes: [10313 10331 10332 10314]
# Quad element 13014: Nodes: [10314 10332 10333 10315]
# Quad element 13015: Nodes: [10315 10333 10334 10316]
# Quad element 13016: Nodes: [10316 10334 10335 10317]
# Quad element 13017: Nodes: [10317 10335 10336 10318]
# Quad element 13018: Nodes: [10318 10336 10337 10319]
# Quad element 13019: Nodes: [10319 10337 10338 10320]
# Quad element 13020: Nodes: [10320 10338 10339 10321]
# Quad element 13021: Nodes: [10321 10339  1036  1035]
# Quad element 13022: Nodes: [  892   893 10340 10322]
# Quad element 13023: Nodes: [10322 10340 10341 10323]
# Quad element 13024: Nodes: [10323 10341 10342 10324]
# Quad element 13025: Nodes: [10324 10342 10343 10325]
# Quad element 13026: Nodes: [10325 10343 10344 10326]
# Quad element 13027: Nodes: [10326 10344 10345 10327]
# Quad element 13028: Nodes: [10327 10345 10346 10328]
# Quad element 13029: Nodes: [10328 10346 10347 10329]
# Quad element 13030: Nodes: [10329 10347 10348 10330]
# Quad element 13031: Nodes: [10330 10348 10349 10331]
# Quad element 13032: Nodes: [10331 10349 10350 10332]
# Quad element 13033: Nodes: [10332 10350 10351 10333]
# Quad element 13034: Nodes: [10333 10351 10352 10334]
# Quad element 13035: Nodes: [10334 10352 10353 10335]
# Quad element 13036: Nodes: [10335 10353 10354 10336]
# Quad element 13037: Nodes: [10336 10354 10355 10337]
# Quad element 13038: Nodes: [10337 10355 10356 10338]
# Quad element 13039: Nodes: [10338 10356 10357 10339]
# Quad element 13040: Nodes: [10339 10357  1037  1036]
# Quad element 13041: Nodes: [  893   894 10358 10340]
# Quad element 13042: Nodes: [10340 10358 10359 10341]
# Quad element 13043: Nodes: [10341 10359 10360 10342]
# Quad element 13044: Nodes: [10342 10360 10361 10343]
# Quad element 13045: Nodes: [10343 10361 10362 10344]
# Quad element 13046: Nodes: [10344 10362 10363 10345]
# Quad element 13047: Nodes: [10345 10363 10364 10346]
# Quad element 13048: Nodes: [10346 10364 10365 10347]
# Quad element 13049: Nodes: [10347 10365 10366 10348]
# Quad element 13050: Nodes: [10348 10366 10367 10349]
# Quad element 13051: Nodes: [10349 10367 10368 10350]
# Quad element 13052: Nodes: [10350 10368 10369 10351]
# Quad element 13053: Nodes: [10351 10369 10370 10352]
# Quad element 13054: Nodes: [10352 10370 10371 10353]
# Quad element 13055: Nodes: [10353 10371 10372 10354]
# Quad element 13056: Nodes: [10354 10372 10373 10355]
# Quad element 13057: Nodes: [10355 10373 10374 10356]
# Quad element 13058: Nodes: [10356 10374 10375 10357]
# Quad element 13059: Nodes: [10357 10375  1038  1037]
# Quad element 13060: Nodes: [  894   895 10376 10358]
# Quad element 13061: Nodes: [10358 10376 10377 10359]
# Quad element 13062: Nodes: [10359 10377 10378 10360]
# Quad element 13063: Nodes: [10360 10378 10379 10361]
# Quad element 13064: Nodes: [10361 10379 10380 10362]
# Quad element 13065: Nodes: [10362 10380 10381 10363]
# Quad element 13066: Nodes: [10363 10381 10382 10364]
# Quad element 13067: Nodes: [10364 10382 10383 10365]
# Quad element 13068: Nodes: [10365 10383 10384 10366]
# Quad element 13069: Nodes: [10366 10384 10385 10367]
# Quad element 13070: Nodes: [10367 10385 10386 10368]
# Quad element 13071: Nodes: [10368 10386 10387 10369]
# Quad element 13072: Nodes: [10369 10387 10388 10370]
# Quad element 13073: Nodes: [10370 10388 10389 10371]
# Quad element 13074: Nodes: [10371 10389 10390 10372]
# Quad element 13075: Nodes: [10372 10390 10391 10373]
# Quad element 13076: Nodes: [10373 10391 10392 10374]
# Quad element 13077: Nodes: [10374 10392 10393 10375]
# Quad element 13078: Nodes: [10375 10393  1039  1038]
# Quad element 13079: Nodes: [  895   896 10394 10376]
# Quad element 13080: Nodes: [10376 10394 10395 10377]
# Quad element 13081: Nodes: [10377 10395 10396 10378]
# Quad element 13082: Nodes: [10378 10396 10397 10379]
# Quad element 13083: Nodes: [10379 10397 10398 10380]
# Quad element 13084: Nodes: [10380 10398 10399 10381]
# Quad element 13085: Nodes: [10381 10399 10400 10382]
# Quad element 13086: Nodes: [10382 10400 10401 10383]
# Quad element 13087: Nodes: [10383 10401 10402 10384]
# Quad element 13088: Nodes: [10384 10402 10403 10385]
# Quad element 13089: Nodes: [10385 10403 10404 10386]
# Quad element 13090: Nodes: [10386 10404 10405 10387]
# Quad element 13091: Nodes: [10387 10405 10406 10388]
# Quad element 13092: Nodes: [10388 10406 10407 10389]
# Quad element 13093: Nodes: [10389 10407 10408 10390]
# Quad element 13094: Nodes: [10390 10408 10409 10391]
# Quad element 13095: Nodes: [10391 10409 10410 10392]
# Quad element 13096: Nodes: [10392 10410 10411 10393]
# Quad element 13097: Nodes: [10393 10411  1040  1039]
# Quad element 13098: Nodes: [  896   897 10412 10394]
# Quad element 13099: Nodes: [10394 10412 10413 10395]
# Quad element 13100: Nodes: [10395 10413 10414 10396]
# Quad element 13101: Nodes: [10396 10414 10415 10397]
# Quad element 13102: Nodes: [10397 10415 10416 10398]
# Quad element 13103: Nodes: [10398 10416 10417 10399]
# Quad element 13104: Nodes: [10399 10417 10418 10400]
# Quad element 13105: Nodes: [10400 10418 10419 10401]
# Quad element 13106: Nodes: [10401 10419 10420 10402]
# Quad element 13107: Nodes: [10402 10420 10421 10403]
# Quad element 13108: Nodes: [10403 10421 10422 10404]
# Quad element 13109: Nodes: [10404 10422 10423 10405]
# Quad element 13110: Nodes: [10405 10423 10424 10406]
# Quad element 13111: Nodes: [10406 10424 10425 10407]
# Quad element 13112: Nodes: [10407 10425 10426 10408]
# Quad element 13113: Nodes: [10408 10426 10427 10409]
# Quad element 13114: Nodes: [10409 10427 10428 10410]
# Quad element 13115: Nodes: [10410 10428 10429 10411]
# Quad element 13116: Nodes: [10411 10429  1041  1040]
# Quad element 13117: Nodes: [  897    18   466 10412]
# Quad element 13118: Nodes: [10412   466   467 10413]
# Quad element 13119: Nodes: [10413   467   468 10414]
# Quad element 13120: Nodes: [10414   468   469 10415]
# Quad element 13121: Nodes: [10415   469   470 10416]
# Quad element 13122: Nodes: [10416   470   471 10417]
# Quad element 13123: Nodes: [10417   471   472 10418]
# Quad element 13124: Nodes: [10418   472   473 10419]
# Quad element 13125: Nodes: [10419   473   474 10420]
# Quad element 13126: Nodes: [10420   474   475 10421]
# Quad element 13127: Nodes: [10421   475   476 10422]
# Quad element 13128: Nodes: [10422   476   477 10423]
# Quad element 13129: Nodes: [10423   477   478 10424]
# Quad element 13130: Nodes: [10424   478   479 10425]
# Quad element 13131: Nodes: [10425   479   480 10426]
# Quad element 13132: Nodes: [10426   480   481 10427]
# Quad element 13133: Nodes: [10427   481   482 10428]
# Quad element 13134: Nodes: [10428   482   483 10429]
# Quad element 13135: Nodes: [10429   483    26  1041]
# Element count:  8664
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 212
#     210     r_large = 0.18
#     211     shell_mesh = Plane_Mesh(1)
# --> 212     shell_mesh.Plane_gmsh(0.1,0.005,r_large-0.085,r_large,0.22)
#     216 print("X COORDS----------------------------- ")
#     217 shell_mesh.PrintCoords(0,1.00e-3,1.0e-5)
#
# File ~/Numerico/radioss_tutorials/inc_forming/test_spring/mesher.py:301, in Plane_Mesh.Plane_gmsh(self, l, lc, r_outer, r_large, l_tot)
#     300 def Plane_gmsh(self,l, lc, r_outer, r_large, l_tot):
# --> 301   create_mesh(self.nodes,self.elnod, l , lc, r_outer, r_large, l_tot)
#     302   self.node_count = len(self.nodes)
#     303   self.elem_count = len(self.elnod)
#
# File ~/Numerico/radioss_tutorials/inc_forming/test_spring/gen.py:289, in create_mesh(nodes, elnod, l, lc, r_outer, r_large, l_tot)
#     286 node_indices = [node_index_map[n] for n in nod[i * num_nodes_per_elem : (i + 1) * num_nodes_per_elem]]
#     287 #print ("Node indices ",node_indices)
#     288 #elnod.append((node_indices[0],node_indices[1],node_indices[2],node_indices[3]))
# --> 289 eln.append(node_indices)
#     290 #print (elnod)
#     291 elcount +=1
#
# NameError: name 'eln' is not defined

# %%
#print (driver_top.elnod)
model.part[0].mesh[0].nodes[0]
# Out:
# (-0.05, -0.05, 0.0)

# %% [markdown]
# import matplotlib.pyplot as plt
# def multitool_rewrite(fnametop,fnamebot,step_angle=90):
#     step_angle
#     angles=np.arange(step_angle,360,step_angle)
#     print(angles)
#
#     data=pd.read_csv(fnametop)
#     data2=pd.read_csv(fnamebot)
#
#
#     data.to_csv(f'multi_tool_{0}.csv',index=False)
#     data2.to_csv(f'multi_tool_{1}.csv',index=False)
#
#
#     data["radio"] = (data.X**2+data.Y**2)**0.5
#     data2["radio"] = (data2.X**2+data2.Y**2)**0.5
#
#     #plt.plot(data.radio)
#
#     out_top=pd.DataFrame()
#
#     out_bot=pd.DataFrame()
#
#     #plt.plot(data.X,data.Y)
#
#     for i,angle in enumerate(angles):
#         #const
#         sin=np.sin(angle*np.pi/180)
#         cos=np.cos(angle*np.pi/180)
#
#         out_top["X"]=cos*data.X-sin*data.Y
#         out_top["Y"]=sin*data.X+cos*data.Y
#         out_top['Z']=data.Z
#
#         out_bot["X"]=cos*data2.X-sin*data2.Y
#         out_bot["Y"]=sin*data2.X+cos*data2.Y
#         out_bot['Z']=data2.Z
#
#         out_top.to_csv('multi_tool_'+str(i*2+2)+'.csv',index=False)
#         out_top.to_csv('multi_tool_'+str(i*2+3)+'.csv',index=False)
#         #plt.plot(out_top.X,out_top.Y)
#
#     files=[]
#     print(i)
#     for k in range(i*2+4):
#         print(k)
#         files.append(f'multi_tool_{k}.csv')
#
#     return files
#
# files=multitool_rewrite("data/multitool_topToolTipPnts.csv","data/multitool_botToolTipPnts.csv",step_angle=45)
