# %%
import pandas as pd

# %%
df = pd.read_csv('force.csv')

# %%
df['f'].plot()
# Out:
# <Axes: >

# %%
pwd
# Out:
# '/home/weldform-pc/Numerico/radioss_tutorials/inc_forming'

# %%
df.plot.scatter(x='t', y='f')
# Out:
# <Axes: xlabel='t', ylabel='f'>
